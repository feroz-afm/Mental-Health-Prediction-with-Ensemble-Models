# %% [markdown]
# <div style="background-color:green; padding:10px; border-radius:8px; text-align:center;">
#   <h1 style="margin:0; color:white; font-size:24px;">Mental Health Prediction with Ensemble Modelss</h1>
# </div>

# %% [markdown]
# ![image.png](attachment:97a79375-a1a1-4b7b-b1c1-6852e0fb2b6d.png)

# %% [markdown]
# <div style="background-color:#e6f2ff; padding:15px; border-radius:10px;">
#   <h3 style="color:#1e90ff; text-align:center;">Mental Health Prediction with Ensemble Models</h3>
#   <p style="color:#333333; font-size:16px;">
#     Mental health issues are becoming increasingly prevalent in today's fast-paced world.
#     Early prediction and identification can help individuals receive timely support.
#     In this notebook, we apply ensemble learning techniques to predict mental health conditions using survey-based data.
#     Models like Random Forest, XGBoost, and Voting Classifiers are used to boost accuracy and robustness.
#     Feature analysis, visualization, and model comparison are included to ensure interpretability.
#     This approach aims to demonstrate how ensemble models can enhance mental health prediction efforts.
#   </p>
# </div>

# %% [markdown]
# <div style="background-color:#f9f9f9; padding:15px; border-radius:10px;">
#   <h3 style="color:#007acc;">Data Import and Directory Check</h3>
#   <p style="color:#007acc; font-size:15px;">
#     This code imports the necessary libraries and checks the dataset folder.
#     It uses <code>os.walk()</code> to list all files inside <code>/kaggle/input</code>.
#     This helps confirm that all required files are available before starting analysis.
#     It's a good practice to run this at the beginning of any Kaggle notebook.
#   </p>
# </div>

# %%
import numpy as np 
import pandas as pd 
import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# /kaggle/input/depression-surveydataset-for-analysis/final_depression_dataset_1.csv
# /kaggle/input/playground-series-s4e11/sample_submission.csv
# /kaggle/input/playground-series-s4e11/train.csv
# /kaggle/input/playground-series-s4e11/test.csv

# %% [markdown]
# <div style="background-color:green; padding:10px; border-radius:8px; text-align:center;">
#   <h1 style="margin:0; color:white; font-size:24px;">Import Libraries</h1>
# </div>

# %%
from sklearn.ensemble import GradientBoostingClassifier, AdaBoostClassifier
from sklearn.linear_model import LogisticRegression, Ridge
from sklearn.model_selection import StratifiedKFold
from sklearn.preprocessing import OneHotEncoder, OrdinalEncoder
from sklearn.impute import SimpleImputer
from sklearn.pipeline import make_pipeline
from sklearn.metrics import accuracy_score
from sklearn.base import clone
from catboost import CatBoostClassifier
from lightgbm import LGBMClassifier
from xgboost import XGBClassifier
from scipy.special import logit
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
import warnings
import pickle
import shutil
import optuna
import json
import os
import gc

warnings.filterwarnings('ignore')

# %% [markdown]
# <div style="background-color:#f9f9f9; padding:15px; border-radius:10px;">
#   <h3 style="color:#007acc;">Configuration Settings</h3>
#   <p style="color:#007acc; font-size:15px;">
#     The <code>CFG</code> class is used to store key configuration values for the notebook.
#     It includes file paths for the training, test, and sample submission data, as well as the original depression dataset.
#     The class also defines the target column, number of folds for cross-validation, and a random seed for reproducibility.
#     Keeping these settings in one place helps maintain cleaner and more manageable code throughout the notebook.
#   </p>
# </div>

# %%
class CFG:
    train_path = '/kaggle/input/playground-series-s4e11/train.csv'
    test_path = '/kaggle/input/playground-series-s4e11/test.csv'
    sample_sub_path = '/kaggle/input/playground-series-s4e11/sample_submission.csv'
    
    original_data_path = '/kaggle/input/depression-surveydataset-for-analysis/final_depression_dataset_1.csv'
    
    target = 'Depression'
    n_folds = 5
    seed = 42

# %% [markdown]
# # Data loading and preprocessing¶

# %%
_train = pd.read_csv(CFG.train_path, index_col='id')
_test = pd.read_csv(CFG.test_path, index_col='id')

# %% [markdown]
# Similar to previous months' playground competitions, the dataset this time is also imbalanced, with the majority consisting of negative cases for depression. The imbalance ratio is not very high, so we won't do any upsampling or downsampling.

# %%
depression_counts = _train.Depression.value_counts(normalize=True).reset_index()
depression_counts.columns = ['Depression', 'Proportion']
palette = {0: sns.color_palette("Set1")[1], 1: sns.color_palette("Set1")[0]}
class_mapping = {0: 'Not Depressed', 1: 'Depressed'}

plt.figure(figsize=(10, 6))
sns.barplot(x='Depression', y='Proportion', data=depression_counts, palette=palette)

plt.title('')
plt.xlabel('')
plt.ylabel('')
plt.xticks([])
plt.yticks([])
plt.ylim(0, 1)

for index, row in depression_counts.iterrows():
    plt.text(row.name, row.Proportion + 0.02, f'{class_mapping[row.name]} ({row.Proportion:.2%})', ha='center', va='bottom', fontsize=12)

sns.despine()
plt.tight_layout()
plt.show()

# %% [markdown]
# There are several categorical columns in the dataset, and some contain missing values. We will leave the missing values as they are, as most of the models we'll be using can handle missing values on their own.
# Some categorical columns have high cardinality, while others have only two unique values.

# %%
cat_cols = _train.select_dtypes(include='object').columns.tolist()
palette = {0: sns.color_palette("Set1")[1], 1: sns.color_palette("Set1")[0]}

fig, axes = plt.subplots(2, 5, figsize=(20, 10))
axes = axes.flatten()
for i, col in enumerate(cat_cols):
    sns.countplot(data=_train, x=col, hue=CFG.target, ax=axes[i], palette=palette)
    axes[i].set_title(f'{col} distribution')
    axes[i].set_ylabel('')
    axes[i].set_xlabel('')

plt.tight_layout()
plt.show()

# %%
fig, ax = plt.subplots(1, 1, figsize=(10, 5))
sns.barplot(
    x=_train[cat_cols].nunique().sort_values(ascending=False).values,
    y=_train[cat_cols].nunique().sort_values(ascending=False).index,
    ax=ax,
    color="grey"
)
ax.set_title('Unique values in categorical columns')

for i, value in enumerate(_train[cat_cols].nunique().sort_values(ascending=False).values):
    ax.text(value, i, f'{value}', va='center')

sns.despine()
plt.show()

# %%
train_null_values = _train.drop(columns=CFG.target).isnull().T
test_null_values = _test.isnull().T

fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(14, 5))

sns.heatmap(train_null_values, cbar=False, ax=axes[0], cmap=sns.light_palette('grey', as_cmap=True))
axes[0].set_title('Train')
axes[0].set_xticks([]) 
axes[0].set_xlabel('')

sns.heatmap(test_null_values, cbar=False, ax=axes[1], cmap=sns.light_palette('grey', as_cmap=True))
axes[1].set_title('Test')
axes[1].set_xticks([]) 
axes[1].set_xlabel('')

plt.tight_layout()
plt.show()

# %% [markdown]
# Below, we'll create a function that:
# Converts the categorical columns to the category datatype.
# Ensures that targets are consistent between the competition and original dataset.
# Makes sure the data types are consistent between the original and competition datasets.
# Divides both datasets into features and targets to be used by the Trainer class later on.

# %%
def get_data(model):
    train = pd.read_csv(CFG.train_path, index_col='id')
    test = pd.read_csv(CFG.test_path, index_col='id')
    original = pd.read_csv(CFG.original_data_path)
    original[CFG.target] = original[CFG.target].map({'Yes': 1, 'No': 0})
    
    if model == 'cb':
        cat_cols = test.columns.tolist()
    else:
        cat_cols = test.select_dtypes(include='object').columns.tolist()
        
    train[cat_cols] = train[cat_cols].astype(str).astype('category')
    test[cat_cols] = test[cat_cols].astype(str).astype('category')
    original[cat_cols] = original[cat_cols].astype(str).astype('category')
        
    for col in cat_cols:
        common_categories = train[col].cat.categories.union(original[col].cat.categories)
        train[col] = train[col].cat.set_categories(common_categories)
        original[col] = original[col].cat.set_categories(common_categories)
    
    for col in train.columns:
        original[col] = original[col].astype(train[col].dtype)

    if model in ['gb', 'adb']:
        encoder = OrdinalEncoder(handle_unknown='use_encoded_value', unknown_value=-1)
        train[cat_cols] = encoder.fit_transform(train[cat_cols])
        test[cat_cols] = encoder.transform(test[cat_cols])
        original[cat_cols] = encoder.transform(original[cat_cols])
    
        cols_with_missing_values = train.columns[train.isnull().mean() > 0]
        imputer = SimpleImputer(strategy='mean')
        train[cols_with_missing_values] = imputer.fit_transform(train[cols_with_missing_values])
        test[cols_with_missing_values] = imputer.transform(test[cols_with_missing_values])
        original[cols_with_missing_values] = imputer.transform(original[cols_with_missing_values])
    
    X = train.drop(CFG.target, axis=1)
    y = train[CFG.target]
    X_test = test
    
    X_original = original.drop(CFG.target, axis=1)
    y_original = original[CFG.target]
    
    return X, y, X_test, X_original, y_original

# %% [markdown]
# # Training base models¶

# %%
class Trainer:
    def __init__(self, model, config=CFG, is_ensemble_model=False):
        self.model = model
        self.config = config
        self.is_ensemble_model = is_ensemble_model

    def fit_predict(self, X, y, X_test, X_original=None, y_original=None, threshold=0.5):
        print(f'Training {self.model.__class__.__name__}\n')
        
        scores = []        
        coeffs = np.zeros((1, X.shape[1]))
        oof_pred_probs = np.zeros(X.shape[0])
        test_pred_probs = np.zeros(X_test.shape[0])
        
        skf = StratifiedKFold(n_splits=self.config.n_folds, random_state=self.config.seed, shuffle=True)
        for fold_idx, (train_idx, val_idx) in enumerate(skf.split(X, y)):
            X_train, X_val = X.iloc[train_idx], X.iloc[val_idx]
            y_train, y_val = y[train_idx], y[val_idx]
            
            if not self.is_ensemble_model:                                
                X_train = pd.concat([X_train, X_original], ignore_index=True)
                y_train = pd.concat([y_train, y_original], ignore_index=True)
            
            model = clone(self.model)
            model.fit(X_train, y_train)
            
            if self.is_ensemble_model:
                coeffs += model.coef_ / self.config.n_folds
                if isinstance(self.model, LogisticRegression):
                    n_iters = model.n_iter_[0]
            
            y_pred_probs = model.predict(X_val) if isinstance(self.model, Ridge) else model.predict_proba(X_val)[: ,1]
            oof_pred_probs[val_idx] = y_pred_probs 
            
            temp_test_pred_probs = model.predict(X_test) if isinstance(self.model, Ridge) else model.predict_proba(X_test)[:, 1]
            test_pred_probs += temp_test_pred_probs / self.config.n_folds
            
            score = accuracy_score(y_val, (y_pred_probs > threshold).astype(int))
            scores.append(score)
            
            del model, X_train, y_train, X_val, y_val, y_pred_probs
            gc.collect()
            
            if self.is_ensemble_model and isinstance(self.model, LogisticRegression):
                print(f'--- Fold {fold_idx + 1} - Accuracy: {score:.6f} ({n_iters} iterations)')
            else:
                print(f'--- Fold {fold_idx + 1} - Accuracy: {score:.6f}')
            
        overall_score = accuracy_score(y, (oof_pred_probs > threshold).astype(int))
            
        print(f'\n------ Overall: {overall_score:.6f} | Average: {np.mean(scores):.6f} ± {np.std(scores):.6f}')
        
        if self.is_ensemble_model:
            return oof_pred_probs, test_pred_probs, scores, coeffs
        else:
            os.makedirs('oof_pred_probs', exist_ok=True)
            os.makedirs('test_pred_probs', exist_ok=True)
            self._save_pred_probs(oof_pred_probs, np.mean(scores), 'oof')
            self._save_pred_probs(test_pred_probs, np.mean(scores), 'test')
            return oof_pred_probs, test_pred_probs, scores
        
    def fit(self, X, y, threshold=0.5):
        scores = []                
        skf = StratifiedKFold(n_splits=self.config.n_folds, random_state=self.config.seed, shuffle=True)
        for fold_idx, (train_idx, val_idx) in enumerate(skf.split(X, y)):
            X_train, X_val = X.iloc[train_idx], X.iloc[val_idx]
            y_train, y_val = y[train_idx], y[val_idx]
            
            model = clone(self.model)
            model.fit(X_train, y_train)
            
            y_pred_probs = model.predict(X_val) if isinstance(self.model, Ridge) else model.predict_proba(X_val)[:, 1]  
            score = accuracy_score(y_val, (y_pred_probs > threshold).astype(int))
            scores.append(score)
            
            del model, X_train, y_train, X_val, y_val, y_pred_probs
            gc.collect() 
        
        return np.mean(scores)
        
    def _save_pred_probs(self, pred_probs, cv_score, name):
        model_name = self.model.__class__.__name__.lower().replace('classifier', '')
        with open(f'{name}_pred_probs/{model_name}_{name}_pred_probs_{cv_score:.6f}.pkl', 'wb') as f:
            pickle.dump(pred_probs, f)

# %%
def save_submission(name, test_pred_probs, score, threshold=0.5):
    sub = pd.read_csv(CFG.sample_sub_path)
    sub[CFG.target] = (test_pred_probs > threshold).astype(int)
    sub.to_csv(f'sub_{name}_{score:.6f}.csv', index=False)
    return sub.head()

# %%
lr_params = {
    "C": 5.559884346567435,
    "max_iter": 1000,
    "n_jobs": 4,
    "penalty": "l2",
    "random_state": 42,
    "solver": "newton-cg",
    "tol": 0.08313081991676836
}

cb_params = {
    "border_count": 180,
    "colsample_bylevel": 0.7351678905666684,
    "depth": 4,
    "iterations": 2372,
    "l2_leaf_reg": 4.442847441200204,
    "learning_rate": 0.0514109059943355,
    "min_child_samples": 146,
    "random_state": 42,
    "random_strength": 0.18678416655567043,
    "scale_pos_weight": 1.019889465491297,
    "subsample": 0.3511896501762123,
    "verbose": False
}

xgb_params = {
    "colsample_bylevel": 0.25155109886677396,
    "colsample_bynode": 0.5723191165109757,
    "colsample_bytree": 0.18034301813835885,
    "enable_categorical": True,
    "gamma": 3.6392698070258622,
    "max_bins": 26161,
    "max_depth": 16,
    "max_leaves": 67,
    "min_child_weight": 34,
    "n_estimators": 3853,
    "n_jobs": -1,
    "random_state": 42,
    "reg_alpha": 7.996080341061729,
    "reg_lambda": 46.83054555763492,
    "scale_pos_weight": 1.2157646356820928,
    "subsample": 0.9117754083869292,
    "verbosity": 0
}

lgbm_params = {
    "boosting_type": "gbdt",
    "colsample_bytree": 0.18283018243382332,
    "learning_rate": 0.09945326391012832,
    "max_bins": 36644,
    "min_child_samples": 105,
    "min_child_weight": 0.2083765599710974,
    "n_estimators": 244,
    "n_jobs": -1,
    "num_leaves": 122,
    "random_state": 42,
    "reg_alpha": 8.662578235164972,
    "reg_lambda": 3.5696291074963926,
    "scale_pos_weight": 1.0733293968870794,
    "subsample": 0.5360642841695424,
    "verbose": -1
}

lgbm_goss_params = {
    "boosting_type": "goss",
    "colsample_bytree": 0.11905309670044416,
    "learning_rate": 0.04641567005485582,
    "max_bins": 18501,
    "min_child_samples": 283,
    "min_child_weight": 0.5242575557671028,
    "n_estimators": 966,
    "n_jobs": -1,
    "num_leaves": 159,
    "random_state": 42,
    "reg_alpha": 8.160196501794122,
    "reg_lambda": 9.861767101758469,
    "scale_pos_weight": 0.991416082619142,
    "subsample": 0.9259030065865966,
    "verbose": -1
}

lgbm_dart_params = {
    "boosting_type": "dart",
    "colsample_bytree": 0.1181378019860333,
    "learning_rate": 0.0910272033595692,
    "max_bins": 7386,
    "min_child_samples": 225,
    "min_child_weight": 0.28492487885169293,
    "n_estimators": 1454,
    "n_jobs": -1,
    "num_leaves": 163,
    "random_state": 42,
    "reg_alpha": 2.9686583338116925,
    "reg_lambda": 9.781841345026509,
    "scale_pos_weight": 0.8309734952725212,
    "subsample": 0.511061530253864,
    "verbose": -1
}

gb_params = {
    'learning_rate': 0.129726178306296,
    'max_depth': 82,
    'max_features': 0.9815414831121304,
    'max_leaf_nodes': 45,
    'min_samples_leaf': 0.0015657248550179637,
    'min_samples_split': 0.3385622260186072,
    'min_weight_fraction_leaf': 0.03201568899384577,
    'n_estimators': 1048,
    'random_state': 42,
    'subsample': 0.9550206349439808
}

adb_params = {
    'learning_rate': 1.5174537517219886,
    'n_estimators': 410,
    'random_state': 42
}

# %%
scores = {}
oof_pred_probs = {}
test_pred_probs = {}

# %%
# Reference: https://www.kaggle.com/competitions/playground-series-s4e11/discussion/543746

X, y, X_test, X_original, y_original = get_data('lr')
lr_model = make_pipeline(
    OneHotEncoder(handle_unknown='ignore', min_frequency=0.001),
    LogisticRegression(**lr_params)
)
lr_trainer = Trainer(lr_model)
oof_pred_probs['LogisticRegression'], test_pred_probs['LogisticRegression'], scores['LogisticRegression'] = lr_trainer.fit_predict(X, y, X_test, X_original, y_original)
# Out:
# Training Pipeline
#
# --- Fold 1 - Accuracy: 0.940689
# --- Fold 2 - Accuracy: 0.938024
# --- Fold 3 - Accuracy: 0.940370
# --- Fold 4 - Accuracy: 0.941222
# --- Fold 5 - Accuracy: 0.938842
#
# ------ Overall: 0.939829 | Average: 0.939829 ± 0.001201

# %%
X, y, X_test, X_original, y_original = get_data("cb")
cb_model = CatBoostClassifier(**cb_params, cat_features=X.columns.tolist())
cb_trainer = Trainer(cb_model)
oof_pred_probs['CatBoost'], test_pred_probs['CatBoost'], scores['CatBoost'] = cb_trainer.fit_predict(X, y, X_test, X_original, y_original)
# Out:
# Training CatBoostClassifier
#
# --- Fold 1 - Accuracy: 0.939908
# --- Fold 2 - Accuracy: 0.939090
# --- Fold 3 - Accuracy: 0.941187
# --- Fold 4 - Accuracy: 0.942075
# --- Fold 5 - Accuracy: 0.940121
#
# ------ Overall: 0.940476 | Average: 0.940476 ± 0.001042

# %%
X, y, X_test, X_original, y_original = get_data("xgb")
xgb_model = XGBClassifier(**xgb_params)
xgb_trainer = Trainer(xgb_model)
oof_pred_probs['XGBoost'], test_pred_probs['XGBoost'], scores['XGBoost'] = xgb_trainer.fit_predict(X, y, X_test, X_original, y_original)
# Out:
# Training XGBClassifier
#
# --- Fold 1 - Accuracy: 0.939055
# --- Fold 2 - Accuracy: 0.936994
# --- Fold 3 - Accuracy: 0.940014
# --- Fold 4 - Accuracy: 0.941898
# --- Fold 5 - Accuracy: 0.939303
#
# ------ Overall: 0.939453 | Average: 0.939453 ± 0.001582

# %%
X, y, X_test, X_original, y_original = get_data("lgbm")
lgbm_model = LGBMClassifier(**lgbm_params)
lgbm_trainer = Trainer(lgbm_model)
oof_pred_probs['LightGBM'], test_pred_probs['LightGBM'], scores['LightGBM'] = lgbm_trainer.fit_predict(X, y, X_test, X_original, y_original)
# Out:
# Training LGBMClassifier
#
# --- Fold 1 - Accuracy: 0.940476
# --- Fold 2 - Accuracy: 0.938664
# --- Fold 3 - Accuracy: 0.941045
# --- Fold 4 - Accuracy: 0.941365
# --- Fold 5 - Accuracy: 0.939979
#
# ------ Overall: 0.940306 | Average: 0.940306 ± 0.000949

# %%
X, y, X_test, X_original, y_original = get_data("lgbm_goss")
lgbm_goss_model = LGBMClassifier(**lgbm_goss_params)
lgbm_goss_trainer = Trainer(lgbm_goss_model)
oof_pred_probs['LightGBM (goss)'], test_pred_probs['LightGBM (goss)'], scores['LightGBM (goss)'] = lgbm_goss_trainer.fit_predict(X, y, X_test, X_original, y_original)
# Out:
# Training LGBMClassifier
#
# --- Fold 1 - Accuracy: 0.940156
# --- Fold 2 - Accuracy: 0.938273
# --- Fold 3 - Accuracy: 0.941613
# --- Fold 4 - Accuracy: 0.941578
# --- Fold 5 - Accuracy: 0.940405
#
# ------ Overall: 0.940405 | Average: 0.940405 ± 0.001220

# %%
X, y, X_test, X_original, y_original = get_data("lgbm_dart")
lgbm_dart_model = LGBMClassifier(**lgbm_dart_params)
lgbm_dart_trainer = Trainer(lgbm_dart_model)
oof_pred_probs['LightGBM (dart)'], test_pred_probs['LightGBM (dart)'], scores['LightGBM (dart)'] = lgbm_dart_trainer.fit_predict(X, y, X_test, X_original, y_original)
# Out:
# Training LGBMClassifier
#
# --- Fold 1 - Accuracy: 0.938877
# --- Fold 2 - Accuracy: 0.938877
# --- Fold 3 - Accuracy: 0.940903
# --- Fold 4 - Accuracy: 0.941791
# --- Fold 5 - Accuracy: 0.939517
#
# ------ Overall: 0.939993 | Average: 0.939993 ± 0.001164

# %%
X, y, X_test, X_original, y_original = get_data("gb")
gb_model = GradientBoostingClassifier(**gb_params)
gb_trainer = Trainer(gb_model)
oof_pred_probs['Gradient Boosting'], test_pred_probs['Gradient Boosting'], scores['Gradient Boosting'] = gb_trainer.fit_predict(X, y, X_test, X_original, y_original)
# Out:
# Training GradientBoostingClassifier
#
# --- Fold 1 - Accuracy: 0.939979
# --- Fold 2 - Accuracy: 0.938593
# --- Fold 3 - Accuracy: 0.941649
# --- Fold 4 - Accuracy: 0.942466
# --- Fold 5 - Accuracy: 0.940050
#
# ------ Overall: 0.940547 | Average: 0.940547 ± 0.001363

# %%
X, y, X_test, X_original, y_original = get_data("adb")
adb_model = AdaBoostClassifier(**adb_params)
adb_trainer = Trainer(adb_model)
oof_pred_probs['AdaBoost'], test_pred_probs['AdaBoost'], scores['AdaBoost'] = adb_trainer.fit_predict(X, y, X_test, X_original, y_original)
# Out:
# Training AdaBoostClassifier
#
# --- Fold 1 - Accuracy: 0.939837
# --- Fold 2 - Accuracy: 0.938415
# --- Fold 3 - Accuracy: 0.939588
# --- Fold 4 - Accuracy: 0.941222
# --- Fold 5 - Accuracy: 0.940334
#
# ------ Overall: 0.939879 | Average: 0.939879 ± 0.000921

# %% [markdown]
# # L2 Logistic Regression
# To ensemble the OOF files of the base models, we will:
#
# Tune and train a LogisticRegression model.
# Tune and train a Ridge model.
# Combine the two ensembles using a weighted average.

# %%
def plot_weights(weights, title):
    sorted_indices = np.argsort(weights[0])[::-1]
    sorted_coeffs = np.array(weights[0])[sorted_indices]
    sorted_model_names = np.array(list(oof_pred_probs.keys()))[sorted_indices]

    plt.figure(figsize=(10, weights.shape[1] * 0.5))
    ax = sns.barplot(x=sorted_coeffs, y=sorted_model_names, palette="RdYlGn_r")

    for i, (value, name) in enumerate(zip(sorted_coeffs, sorted_model_names)):
        if value >= 0:
            ax.text(value, i, f'{value:.3f}', va='center', ha='left', color='black')
        else:
            ax.text(value, i, f'{value:.3f}', va='center', ha='right', color='black')

    xlim = ax.get_xlim()
    ax.set_xlim(xlim[0] - 0.1 * abs(xlim[0]), xlim[1] + 0.1 * abs(xlim[1]))

    plt.title(title)
    plt.xlabel('')
    plt.ylabel('')
    plt.tight_layout()
    plt.show()

# %%
def objective(trial):
    solver_penalty_options = [
        ('liblinear', 'l1'),
        ('liblinear', 'l2'),
        ('lbfgs', 'l2'),
        ('lbfgs', None),
        ('newton-cg', 'l2'),
        ('newton-cg', None),
        ('newton-cholesky', 'l2'),
        ('newton-cholesky', None)
    ]
    solver, penalty = trial.suggest_categorical('solver_penalty', solver_penalty_options)
    
    params = {
        'random_state': CFG.seed,
        'max_iter': 500,
        'C': trial.suggest_float('C', 0, 10),
        'tol': trial.suggest_float('tol', 1e-10, 1e-1),
        'fit_intercept': trial.suggest_categorical('fit_intercept', [True, False]),
        'class_weight': trial.suggest_categorical('class_weight', ['balanced', None]),
        'solver': solver,
        'penalty': penalty
    }
    
    threshold = trial.suggest_float('threshold', 0.4, 0.6, step=0.001)
    
    model = LogisticRegression(**params)
    trainer = Trainer(model, is_ensemble_model=True)
    return trainer.fit(X, y, threshold)

sampler = optuna.samplers.TPESampler(seed=CFG.seed, multivariate=True)
study = optuna.create_study(direction='maximize', sampler=sampler)
study.optimize(objective, n_trials=50, n_jobs=-1)
best_params = study.best_params
# Out:
# [I 2025-07-09 18:15:10,168] A new study created in memory with name: no-name-02d456e0-f913-424c-b509-dcadb648ab31
# [I 2025-07-09 18:15:14,872] Trial 0 finished with value: 0.9047761194029851 and parameters: {'solver_penalty': ('newton-cholesky', None), 'C': 3.8188508364323437, 'tol': 0.0483966624601859, 'fit_intercept': True, 'class_weight': 'balanced', 'threshold': 0.438}. Best is trial 0 with value: 0.9047761194029851.
# [I 2025-07-09 18:15:15,065] Trial 3 finished with value: 0.9201492537313433 and parameters: {'solver_penalty': ('newton-cholesky', None), 'C': 3.1913685617688206, 'tol': 0.011833614075641742, 'fit_intercept': False, 'class_weight': 'balanced', 'threshold': 0.5650000000000001}. Best is trial 3 with value: 0.9201492537313433.
# [I 2025-07-09 18:15:15,479] Trial 2 finished with value: 0.9364108031272209 and parameters: {'solver_penalty': ('newton-cholesky', None), 'C': 5.460226134372942, 'tol': 0.05390693147832766, 'fit_intercept': True, 'class_weight': None, 'threshold': 0.56}. Best is trial 2 with value: 0.9364108031272209.
# [I 2025-07-09 18:15:19,822] Trial 4 finished with value: 0.9103553660270078 and parameters: {'solver_penalty': ('liblinear', 'l1'), 'C': 3.4686849209453987, 'tol': 0.08061211671011274, 'fit_intercept': False, 'class_weight': None, 'threshold': 0.5920000000000001}. Best is trial 2 with value: 0.9364108031272209.
# [I 2025-07-09 18:15:24,056] Trial 1 finished with value: 0.9163113006396587 and parameters: {'solver_penalty': ('liblinear', 'l2'), 'C': 6.678038200767022, 'tol': 0.00882324698872111, 'fit_intercept': True, 'class_weight': 'balanced', 'threshold': 0.533}. Best is trial 2 with value: 0.9364108031272209.
# [I 2025-07-09 18:15:30,824] Trial 6 finished with value: 0.9110803127221037 and parameters: {'solver_penalty': ('liblinear', 'l1'), 'C':
. Best is trial 17 with value: 0.9373845060412224.
# [I 2025-07-09 18:18:20,115] Trial 24 finished with value: 0.9373063255152807 and parameters: {'solver_penalty': ('newton-cg', None), 'C': 6.33517737399202, 'tol': 0.0890147004180989, 'fit_intercept': True, 'class_weight': None, 'threshold': 0.505}. Best is trial 17 with value: 0.9373845060412224.
# [I 2025-07-09 18:18:43,560] Trial 20 finished with value: 0.936275764036958 and parameters: {'solver_penalty': ('lbfgs', None), 'C': 6.852046854041369, 'tol': 0.09864729627291458, 'fit_intercept': True, 'class_weight': None, 'threshold': 0.462}. Best is trial 17 with value: 0.9373845060412224.
# [I 2025-07-09 18:19:09,072] Trial 28 finished with value: 0.9361833688699359 and parameters: {'solver_penalty': ('lbfgs', None), 'C': 6.940866730487429, 'tol': 0.06930498926678298, 'fit_intercept': False, 'class_weight': None, 'threshold': 0.454}. Best is trial 17 with value: 0.9373845060412224.
# [I 2025-07-09 18:19:25,759] Trial 33 finished with value: 0.9365813788201848 and parameters: {'solver_penalty': ('newton-cg', None), 'C': 6.19019433822992, 'tol': 0.0954745589501273, 'fit_intercept': True, 'class_weight': None, 'threshold': 0.42700000000000005}. Best is trial 17 with value: 0.9373845060412224.
# [I 2025-07-09 18:19:46,882] Trial 34 finished with value: 0.9372707889125799 and parameters: {'solver_penalty': ('newton-cg', None), 'C': 6.103065501687504, 'tol': 0.08456375637419514, 'fit_intercept': True, 'class_weight': None, 'threshold': 0.512}. Best is trial 17 with value: 0.9373845060412224.
# [I 2025-07-09 18:19:51,432] Trial 37 finished with value: 0.9138805970149253 and parameters: {'solver_penalty': ('newton-cholesky', 'l2'), 'C': 3.7345165621303886, 'tol': 0.07502578615154348, 'fit_intercept': True, 'class_weight': 'balanced', 'threshold': 0.503}. Best is trial 17 with value: 0.9373845060412224.
# [I 2025-07-09 18:19:58,742] Trial 38 finished with value: 0.875636105188344 and parameters: {'solver_penalty': ('liblinear', 'l2'), 'C': 8.909037338530997, 'tol': 0.09859535224140388, 'fit_intercept': True, 'class_weight': None, 'threshold': 0.557}. Best is trial 17 with value: 0.9373845060412224.
# [I 2025-07-09 18:19:59,644] Trial 32 finished with value: 0.9351172707889127 and parameters: {'solver_penalty': ('lbfgs', 'l2'), 'C': 7.779697137000715, 'tol': 0.09666869522397455, 'fit_intercept': True, 'class_weight': None, 'threshold': 0.589}. Best is trial 17 with value: 0.9373845060412224.
# [I 2025-07-09 18:20:04,727] Trial 40 finished with value: 0.9372707889125799 and parameters: {'solver_penalty': ('newton-cholesky', 'l2'), 'C': 5.056150032922563, 'tol': 0.05707825960949879, 'fit_intercept': True, 'class_weight': None, 'threshold': 0.47700000000000004}. Best is trial 17 with value: 0.9373845060412224.
# [I 2025-07-09 18:20:09,293] Trial 41 finished with value: 0.918315565031983 and parameters: {'solver_penalty': ('liblinear', 'l1'), 'C': 7.115022948280755, 'tol': 0.09029620268580195, 'fit_intercept': True, 'class_weight': None, 'threshold': 0.515}. Best is trial 17 with value: 0.9373845060412224.
# [I 2025-07-09 18:20:17,023] Trial 42 finished with value: 0.8793034825870647 and parameters: {'solver_penalty': ('liblinear', 'l2'), 'C': 3.8248058521070227, 'tol': 0.07585197908698141, 'fit_intercept': True, 'class_weight': None, 'threshold': 0.526}. Best is trial 17 with value: 0.9373845060412224.
# [I 2025-07-09 18:20:17,567] Trial 35 finished with value: 0.9374413646055437 and parameters: {'solver_penalty': ('newton-cg', None), 'C': 8.456481067878231, 'tol': 0.09308057429953047, 'fit_intercept': True, 'class_weight': None, 'threshold': 0.5}. Best is trial 35 with value: 0.9374413646055437.
# [I 2025-07-09 18:20:33,352] Trial 36 finished with value: 0.9372707889125799 and parameters: {'solver_penalty': ('newton-cg', None), 'C': 6.837472344423982, 'tol': 0.09069396474254046, 'fit_intercept': True, 'class_weight': None, 'threshold': 0.512}. Best is trial 35 with value: 0.9374413646055437.
# [I 2025-07-09 18:21:20,539] Trial 43 finished with value: 0.9373063255152807 and parameters: {'solver_penalty': ('newton-cg', 'l2'), 'C': 9.43260125033051, 'tol': 0.08609282554472254, 'fit_intercept': True, 'class_weight': None, 'threshold': 0.47600000000000003}. Best is trial 35 with value: 0.9374413646055437.
# [I 2025-07-09 18:21:22,847] Trial 44 finished with value: 0.9373276474769012 and parameters: {'solver_penalty': ('newton-cg', None), 'C': 9.01946377461734, 'tol': 0.06533833838529908, 'fit_intercept': True, 'class_weight': None, 'threshold': 0.48500000000000004}. Best is trial 35 with value: 0.9374413646055437.
# [I 2025-07-09 18:21:38,365] Trial 39 finished with value: 0.9365245202558634 and parameters: {'solver_penalty': ('lbfgs', 'l2'), 'C': 5.727254161170249, 'tol': 0.07347874102438205, 'fit_intercept': True, 'class_weight': None, 'threshold': 0.507}. Best is trial 35 with value: 0.9374413646055437.
# [I 2025-07-09 18:22:10,935] Trial 45 finished with value: 0.9366240227434257 and parameters: {'solver_penalty': ('lbfgs', 'l2'), 'C': 6.453775016180065, 'tol': 0.06672648762418897, 'fit_intercept': True, 'class_weight': None, 'threshold': 0.494}. Best is trial 35 with value: 0.9374413646055437.
# [I 2025-07-09 18:22:14,718] Trial 46 finished with value: 0.9085572139303482 and parameters: {'solver_penalty': ('newton-cg', None), 'C': 9.518264447936932, 'tol': 0.09309875597702057, 'fit_intercept': True, 'class_weight': 'balanced', 'threshold': 0.463}. Best is trial 35 with value: 0.9374413646055437.
# [I 2025-07-09 18:22:18,790] Trial 47 finished with value: 0.9373134328358208 and parameters: {'solver_penalty': ('newton-cg', None), 'C': 8.975394190798736, 'tol': 0.0555601190066642, 'fit_intercept': True, 'class_weight': None, 'threshold': 0.47400000000000003}. Best is trial 35 with value: 0.9374413646055437.
# [I 2025-07-09 18:22:22,890] Trial 48 finished with value: 0.9371073205401563 and parameters: {'solver_penalty': ('newton-cg', None), 'C': 9.921477150366222, 'tol': 0.05571568811154621, 'fit_intercept': True, 'class_weight': None, 'threshold': 0.466}. Best is trial 35 with value: 0.9374413646055437.
# [I 2025-07-09 18:22:29,607] Trial 49 finished with value: 0.9367093105899077 and parameters: {'solver_penalty': ('newton-cg', None), 'C': 8.99988838588758, 'tol': 0.030798590678404285, 'fit_intercept': True, 'class_weight': None, 'threshold': 0.44}. Best is trial 35 with value: 0.9374413646055437.

# %%
l2_oof_pred_probs = {}
l2_test_pred_probs = {}

# %%
X = logit(pd.DataFrame(oof_pred_probs).clip(1e-15, 1-1e-15))
X_test = logit(pd.DataFrame(test_pred_probs).clip(1e-15, 1-1e-15))

# %%
solver, penalty = best_params['solver_penalty']
lr_params = {
    'random_state': CFG.seed,
    'max_iter': 500,
    'C': best_params['C'],
    'tol': best_params['tol'],
    'fit_intercept': best_params['fit_intercept'],
    'class_weight': best_params['class_weight'],
    'solver': solver,
    'penalty': penalty
}

# %%
print(json.dumps(lr_params, indent=2))
# Out:
# {
#   "random_state": 42,
#   "max_iter": 500,
#   "C": 8.456481067878231,
#   "tol": 0.09308057429953047,
#   "fit_intercept": true,
#   "class_weight": null,
#   "solver": "newton-cg",
#   "penalty": null
# }

# %%
best_threshold = study.best_params['threshold']
print(f'Best threshold: {best_threshold:.3f}')
# Out:
# Best threshold: 0.500

# %%
lr_model = LogisticRegression(**lr_params)
lr_trainer = Trainer(lr_model, is_ensemble_model=True)
l2_oof_pred_probs['l2-ensemble-lr'], l2_test_pred_probs['l2-ensemble-lr'], scores['L2 Ensemble LR'], lr_coeffs = lr_trainer.fit_predict(X, y, X_test, None, None, best_threshold)
# Out:
# Training LogisticRegression
#
# --- Fold 1 - Accuracy: 0.940903 (12 iterations)
# --- Fold 2 - Accuracy: 0.939126 (14 iterations)
# --- Fold 3 - Accuracy: 0.941649 (14 iterations)
# --- Fold 4 - Accuracy: 0.941969 (12 iterations)
# --- Fold 5 - Accuracy: 0.940689 (12 iterations)
#
# ------ Overall: 0.940867 | Average: 0.940867 ± 0.000989

# %%
save_submission('l2-ensemble-lr', l2_test_pred_probs['l2-ensemble-lr'], np.mean(scores['L2 Ensemble LR']), best_threshold)
# Out:
#        id  Depression
# 0  140700           0
# 1  140701           0
# 2  140702           0
# 3  140703           1
# 4  140704           0

# %%
plot_weights(lr_coeffs, 'LR Coefficients')

# %% [markdown]
# # L2 Ridge¶

# %%
X = pd.DataFrame(oof_pred_probs)
X_test = pd.DataFrame(test_pred_probs)

# %%
def objective(trial):    
    params = {
        'random_state': CFG.seed,
        'alpha': trial.suggest_float('alpha', 0, 50),
        'tol': trial.suggest_float('tol', 1e-10, 1e-2),
        'positive': trial.suggest_categorical('positive', [True, False]),
        'fit_intercept': trial.suggest_categorical('fit_intercept', [True, False])
    }
    
    threshold = trial.suggest_float('threshold', 0.4, 0.6, step=0.001)
    
    model = Ridge(**params)
    trainer = Trainer(model, is_ensemble_model=True)
    return trainer.fit(X, y, threshold)


sampler = optuna.samplers.TPESampler(seed=CFG.seed, multivariate=True)
study = optuna.create_study(direction='maximize', sampler=sampler)
study.optimize(objective, n_trials=50, n_jobs=-1)
best_params = study.best_params
# Out:
# [I 2025-07-09 18:22:32,966] A new study created in memory with name: no-name-147675f5-b365-4d21-b894-f88284490fb1
# [I 2025-07-09 18:22:35,635] Trial 0 finished with value: 0.9408528784648187 and parameters: {'alpha': 32.31791151074809, 'tol': 0.008035594332288235, 'positive': False, 'fit_intercept': True, 'threshold': 0.496}. Best is trial 0 with value: 0.9408528784648187.
# [I 2025-07-09 18:22:36,001] Trial 2 finished with value: 0.9393532338308457 and parameters: {'alpha': 17.283607680272628, 'tol': 0.004392682982270182, 'positive': False, 'fit_intercept': True, 'threshold': 0.40800000000000003}. Best is trial 0 with value: 0.9408528784648187.
# [I 2025-07-09 18:22:37,009] Trial 3 finished with value: 0.9398294243070362 and parameters: {'alpha': 43.556607319706266, 'tol': 0.008334668419102053, 'positive': True, 'fit_intercept': True, 'threshold': 0.5860000000000001}. Best is trial 0 with value: 0.9408528784648187.
# [I 2025-07-09 18:22:37,349] Trial 1 finished with value: 0.9401492537313432 and parameters: {'alpha': 23.777622329090736, 'tol': 0.008089327407064016, 'positive': True, 'fit_intercept': False, 'threshold': 0.5700000000000001}. Best is trial 0 with value: 0.9408528784648187.
# [I 2025-07-09 18:22:38,988] Trial 5 finished with value: 0.9395380241648897 and parameters: {'alpha': 1.6767179183627523, 'tol': 0.00038576614567371144, 'positive': False, 'fit_intercept': False, 'threshold': 0.41500000000000004}. Best is trial 0 with value: 0.9408528784648187.
# [I 2025-07-09 18:22:39,772] Trial 4 finished with value: 0.9404690831556504 and parameters: {'alpha': 13.689572984347409, 'tol': 0.005122342798487578, 'positive': True, 'fit_intercept': True, 'threshold': 0.466}. Best is trial 0 with value: 0.9408528784648187.
# [I 2025-07-09 18:22:40,154] Trial 6 finished with value: 0.9402061122956645 and parameters: {'alpha': 0.8760490603880566, 'tol': 0.0030508919222072784, 'positive': False, 'fit_intercept': False, 'threshold': 0.452}. Best is trial 0 with value: 0.9408528784648187.
# [I 2025-07-09 18:22:42,266] Trial 8 finished with value: 0.9398862828713576 and parameters: {'alpha': 30.786427047078753, 'tol': 0.00017329256004492625, 'positive': False, 'fit_intercept': False, 'threshold': 0.585}. Best is trial 0 with value: 0.9408528784648187.
# [I 2025-07-09 18:22:42,447] Trial 7 finished with value: 0.9396730632551528 and parameters: {'alpha': 36.13806448261263, 'tol': 0.007349932873088874, 'positive': True, 'fit_intercept': True, 'threshold': 0.5960000000000001}. Best is trial 0 with value: 0.9408528784648187.
# [I 2025-07-09 18:22:43,237] Trial 10 finished with value: 0.9396090973702913 and parameters: {'alpha': 23.66202482437408, 'tol': 0.005387425875173611, 'positive': False, 'fit_intercept': False, 'threshold': 0.595}. Best is trial 0 with value: 0.9408528784648187.
# [I 2025-07-09 18:22:44,528] Trial 9 finished with value: 0.9406538734896944 and parameters: {'alpha': 20.751945748485085, 'tol': 0.00013389667330936876, 'positive': True, 'fit_intercept': False, 'threshold': 0.544}. Best is trial 0 with value: 0.9408528784648187.
# [I 2025-07-09 18:22:46,449] Trial 13 finished with value: 0.9409310589907605 and parameters: {'alpha': 38.991998376976674, 'tol': 0.008802105902147871, 'positive': False, 'fit_intercept': True, 'threshold': 0.492}. Best is trial 13 with value: 0.9409310589907605.
# [I 2025-07-09 18:22:46,805] Trial 11 finished with value: 0.9405401563610518 and parameters: {'alpha': 4.655687243352369, 'tol': 0.004945844400551233, 'positive': True, 'fit_intercept': False, 'threshold': 0.47200000000000003}. Best is trial 13 with value: 0.9409310589907605.
# [I 2025-07-09 18:22:46,996] Trial 12 finished with value: 0.940774697938877 and parameters: {'alpha': 36.504093132527544, 'tol': 0.005435427396098372, 'positive': True, 'fit_intercept': True, 'threshold': 0.5}. Best is trial 13 with value: 0.9409310589907605.
# [I 2025-07-09 18:22:47,774] Trial 14 finished with value: 0.9408031272210376 and parameters: {'alpha': 30.301782068791233, 'tol': 0.007439401898537632, 'positive': False, 'fit_intercept': True, 'threshold': 0.514}. Best is trial 13 with value: 0.9409310589907605.
# [I 2025-07-09 18:22:49,749] Trial 15 finished with value: 0.9403482587064677 and parameters: {'alpha': 31.159928096239597, 'tol': 0.009525285726365795, 'positive': False, 'fit_intercept': True, 'threshold': 0.453}. Best is trial 13 with value: 0.9409310589907605.
# [I 2025-07-09 18:22:50,463] Trial 16 finished with value: 0.9407889125799572 and parameters: {'alpha': 33.772546190793356, 'tol': 0.009447025297453965, 'positive': False, 'fit_intercept': True, 'threshold': 0.514}. Best is trial 13 with value: 0.9409310589907605.
# [I 2025-07-09 18:22:50,635] Trial 17 finished with value: 0.9402487562189055 and parameters: {'alpha': 34.93727303303369, 'tol': 0.009315215511143306, 'positive': False, 'fit_intercept': True, 'threshold': 0.439}. Best is trial 13 with value: 0.9409310589907605.
# [I 2025-07-09 18:22:51,214] Trial 18 finished with value: 0.9392750533049039 and parameters: {'alpha': 37.74561294718795, 'tol': 0.007752431370613318, 'positive': False, 'fit_intercept': True, 'threshold': 0.404}. Best is trial 13 with value: 0.9409310589907605.
# [I 2025-07-09 18:22:53,664] Trial 19 finished with value: 0.9407960199004975 and parameters: {'alpha': 49.455009125237744, 'tol': 0.006707668569070064, 'positive': False, 'fit_intercept': True, 'threshold': 0.489}. Best is trial 13 with value: 0.9409310589907605.
# [I 2025-07-09 18:22:54,032] Trial 20 finished with value: 0.9404904051172707 and parameters: {'alpha': 47.195991786114234, 'tol': 0.009562773670682527, 'positive': False, 'fit_intercept': False, 'threshold': 0.46900000000000003}. Best is trial 13 with value: 0.9409310589907605.
# [I 2025-07-09 18:22:54,410] Trial 21 finished with value: 0.9408599857853588 and parameters: {'alpha': 45.78623570000317, 'tol': 0.0057052229808308205, 'positive': False, 'fit_intercept': True, 'threshold': 0.495}. Best is trial 13 with value: 0.9409310589907605.
# [I 2025-07-09 18:22:54,785] Trial 22 finished with value: 0.9406396588486141 and parameters: {'alpha': 48.54229426138322, 'tol': 0.00765982519087627, 'positive': False, 'fit_intercept': False, 'threshold': 0.542}. Best is trial 13 with value: 0.9409310589907605.
# [I 2025-07-09 18:22:56,925] Trial 23 finished with value: 0.9407036247334755 and parameters: {'alpha': 13.868730296743065, 'tol': 0.0098769358187818, 'positive': False, 'fit_intercept': False, 'threshold': 0.47600000000000003}. Best is trial 13 with value: 0.9409310589907605.
# [I 2025-07-09 18:22:57,663] Trial 24 finished with value: 0.9406041222459134 and parameters: {'alpha': 21.532066900837556, 'tol': 0.006021570770140514, 'positive': False, 'fit_intercept': True, 'threshold': 0.526}. Best is trial 13 with value: 0.9409310589907605.
# [I 2025-07-09 18:22:58,034] Trial 25 finished with value: 0.9407178393745559 and parameters: {'alpha': 41.53060436947331, 'tol': 0.00578886627931955, 'positive': False, 'fit_intercept': False, 'threshold': 0.519}. Best is trial 13 with value: 0.9409310589907605.
# [I 2025-07-09 18:22:58,421] Trial 26 finished with value: 0.9407960199004975 and parameters: {'alpha': 37.22326840934418, 'tol': 0.0020658627102428722, 'positive': False, 'fit_intercept': True, 'threshold': 0.498}. Best is trial 13 with value: 0.9409310589907605.
# [I 2025-07-09 18:23:00,556] Trial 27 finished with value: 0.940547263681592 and parameters: {'alpha': 37.52334176722479, 'tol': 0.004973816083562765, 'positive': False, 'fit_intercept': True, 'threshold': 0.531}. Best is trial 13 with value: 0.9409310589907605.
# [I 2025-07-09 18:23:01,285] Trial 28 finished with value: 0.9406467661691542 and parameters: {'alpha': 41.204931704660865, 'tol': 0.0038452034481759965, 'positive': False, 'fit_intercept': True, 'threshold': 0.537}. Best is trial 13 with value: 0.9409310589907605.
# [I 2025-07-09 18:23:01,812] Trial 29 finished with value: 0.9404264392324094 and parameters: {'alpha': 31.9271349529296, 'tol': 0.0035401855121080577, 'positive': False, 'fit_intercept': True, 'threshold': 0.46}. Best is trial 13 with value: 0.9409310589907605.
# [I 2025-07-09 18:23:02,206] Trial 30 finished with value: 0.9403695806680881 and parameters: {'alpha': 48.32517460231668, 'tol': 0.0032091237859782204, 'positive': False, 'fit_intercept': True, 'threshold': 0.452}. Best is trial 13 with value: 0.9409310589907605.
# [I 2025-07-09 18:23:03,868] Trial 31 finished with value: 0.9401918976545842 and parameters: {'alpha': 47.500980372297526, 'tol': 0.0018719239708810593, 'positive': False, 'fit_intercept': False, 'threshold': 0.443}. Best is trial 13 with value: 0.9409310589907605.
# [I 2025-07-09 18:23:04,840] Trial 32 finished with value: 0.9403909026297088 and parameters: {'alpha': 37.40574623372995, 'tol': 0.005043939586293394, 'positive': False, 'fit_intercept': True, 'threshold': 0.454}. Best is trial 13 with value: 0.9409310589907605.
# [I 2025-07-09 18:23:05,782] Trial 34 finished with value: 0.9408742004264392 and parameters: {'alpha': 37.324299972087964, 'tol': 0.007427517928625225, 'positive': False, 'fit_intercept': True, 'threshold': 0.504}. Best is trial 13 with value: 0.9409310589907605.
# [I 2025-07-09 18:23:06,149] Trial 33 finished with value: 0.9403909026297086 and parameters: {'alpha': 28.938150758935826, 'tol': 0.007237012192549288, 'positive': True, 'fit_intercept': False, 'threshold': 0.452}. Best is trial 13 with value: 0.9409310589907605.
# [I 2025-07-09 18:23:07,611] Trial 35 finished with value: 0.9408386638237385 and parameters: {'alpha': 32.292028191010196, 'tol': 0.0074360221738606885, 'positive': False, 'fit_intercept': True, 'threshold': 0.507}. Best is trial 13 with value: 0.9409310589907605.
# [I 2025-07-09 18:23:08,380] Trial 36 finished with value: 0.9408670931058991 and parameters: {'alpha': 31.2001130220545, 'tol': 0.00717042262922959, 'positive': False, 'fit_intercept': True, 'threshold': 0.506}. Best is trial 13 with value: 0.9409310589907605.
# [I 2025-07-09 18:23:09,119] Trial 37 finished with value: 0.9407320540156361 and parameters: {'alpha': 28.78581928168329, 'tol': 0.007672009394576624, 'positive': False, 'fit_intercept': False, 'threshold': 0.48100000000000004}. Best is trial 13 with value: 0.9409310589907605.
# [I 2025-07-09 18:23:10,125] Trial 38 finished with value: 0.9406680881307746 and parameters: {'alpha': 2.5450058821874855, 'tol': 0.008915744241035571, 'positive': True, 'fit_intercept': True, 'threshold': 0.539}. Best is trial 13 with value: 0.9409310589907605.
# [I 2025-07-09 18:23:11,838] Trial 39 finished with value: 0.9405401563610519 and parameters: {'alpha': 41.572858348162015, 'tol': 0.008072653848612048, 'positive': True, 'fit_intercept': True, 'threshold': 0.514}. Best is trial 13 with value: 0.9409310589907605.
# [I 2025-07-09 18:23:12,227] Trial 41 finished with value: 0.94044776119403 and parameters: {'alpha': 41.03980211507683, 'tol': 0.007910626606945496, 'positive': False, 'fit_intercept': True, 'threshold': 0.56}. Best is trial 13 with value: 0.9409310589907605.
# [I 2025-07-09 18:23:12,640] Trial 40 finished with value: 0.9405543710021321 and parameters: {'alpha': 47.31638414205726, 'tol': 0.007141936824862876, 'positive': True, 'fit_intercept': True, 'threshold': 0.48300000000000004}. Best is trial 13 with value: 0.9409310589907605.
# [I 2025-07-09 18:23:14,804] Trial 42 finished with value: 0.9404832977967306 and parameters: {'alpha': 43.99947790083907, 'tol': 0.009884697995466018, 'positive': True, 'fit_intercept': True, 'threshold': 0.47800000000000004}. Best is trial 13 with value: 0.9409310589907605.
# [I 2025-07-09 18:23:15,347] Trial 43 finished with value: 0.9407249466950958 and parameters: {'alpha': 37.480534860703756, 'tol': 0.007571325424673717, 'positive': False, 'fit_intercept': True, 'threshold': 0.48000000000000004}. Best is trial 13 with value: 0.9409310589907605.
# [I 2025-07-09 18:23:15,740] Trial 44 finished with value: 0.940092395167022 and parameters: {'alpha': 1.2166117313840665, 'tol': 0.008058892334897042, 'positive': False, 'fit_intercept': True, 'threshold': 0.43200000000000005}. Best is trial 13 with value: 0.9409310589907605.
# [I 2025-07-09 18:23:16,137] Trial 45 finished with value: 0.9405970149253731 and parameters: {'alpha': 22.003549732723997, 'tol': 0.007169145325193182, 'positive': False, 'fit_intercept': True, 'threshold': 0.47400000000000003}. Best is trial 13 with value: 0.9409310589907605.
# [I 2025-07-09 18:23:18,318] Trial 46 finished with value: 0.9407675906183369 and parameters: {'alpha': 38.31130064240587, 'tol': 0.00859953754455604, 'positive': False, 'fit_intercept': True, 'threshold': 0.499}. Best is trial 13 with value: 0.9409310589907605.
# [I 2025-07-09 18:23:18,844] Trial 47 finished with value: 0.940724946695096 and parameters: {'alpha': 42.62663197305854, 'tol': 0.008243592388853936, 'positive': False, 'fit_intercept': True, 'threshold': 0.516}. Best is trial 13 with value: 0.9409310589907605.
# [I 2025-07-09 18:23:19,384] Trial 49 finished with value: 0.9408386638237385 and parameters: {'alpha': 39.408589773782964, 'tol': 0.009763676256886313, 'positive': False, 'fit_intercept': True, 'threshold': 0.496}. Best is trial 13 with value: 0.9409310589907605.
# [I 2025-07-09 18:23:19,571] Trial 48 finished with value: 0.9407889125799574 and parameters: {'alpha': 23.697682905437865, 'tol': 0.008730230174514332, 'positive': True, 'fit_intercept': True, 'threshold': 0.499}. Best is trial 13 with value: 0.9409310589907605.

# %%
ridge_params = {
    'random_state': CFG.seed,
    'alpha': best_params['alpha'],
    'tol': best_params['tol'],
    'positive': best_params['positive'],
    'fit_intercept': best_params['fit_intercept']
}

# %%
print(json.dumps(ridge_params, indent=2))
# Out:
# {
#   "random_state": 42,
#   "alpha": 38.991998376976674,
#   "tol": 0.008802105902147871,
#   "positive": false,
#   "fit_intercept": true
# }

# %%
best_threshold = study.best_params['threshold']
print(f'Best threshold: {best_threshold:.3f}')
# Out:
# Best threshold: 0.492

# %%
ridge_model = Ridge(**ridge_params)
ridge_trainer = Trainer(ridge_model, is_ensemble_model=True)
l2_oof_pred_probs['l2-ensemble-ridge'], l2_test_pred_probs['l2-ensemble-ridge'], scores['L2 Ensemble Ridge'], ridge_coeffs = ridge_trainer.fit_predict(X, y, X_test, None, None, best_threshold)
# Out:
# Training Ridge
#
# --- Fold 1 - Accuracy: 0.941080
# --- Fold 2 - Accuracy: 0.939055
# --- Fold 3 - Accuracy: 0.941969
# --- Fold 4 - Accuracy: 0.941862
# --- Fold 5 - Accuracy: 0.940689
#
# ------ Overall: 0.940931 | Average: 0.940931 ± 0.001053

# %%
save_submission('l2-ensemble-ridge', l2_test_pred_probs['l2-ensemble-ridge'], np.mean(scores['L2 Ensemble Ridge']), best_threshold)
# Out:
#        id  Depression
# 0  140700           0
# 1  140701           0
# 2  140702           0
# 3  140703           1
# 4  140704           0

# %%
plot_weights(ridge_coeffs, 'Ridge Coefficients')

# %% [markdown]
# # L3 Weighted ensemble¶

# %%
def objective(trial):
    weights = np.array([trial.suggest_float(l2_model_name, 0, 1) for l2_model_name in l2_oof_pred_probs.keys()])
    weights /= np.sum(weights)
    
    preds = np.zeros(len(y))
    for model, weight in zip(l2_oof_pred_probs.keys(), weights):
        preds += l2_oof_pred_probs[model] * weight
        
    threshold = trial.suggest_float('threshold', 0.4, 0.6, step=0.001)
            
    return accuracy_score(y, (preds > threshold).astype(int))

sampler = optuna.samplers.TPESampler(seed=CFG.seed, multivariate=True)
study = optuna.create_study(direction='maximize', sampler=sampler)
study.optimize(objective, n_trials=100, n_jobs=-1)
# Out:
# [I 2025-07-09 18:23:21,592] A new study created in memory with name: no-name-54b6ccc3-1c59-4818-9c5c-027db408b58d
# [I 2025-07-09 18:23:21,626] Trial 1 finished with value: 0.939957356076759 and parameters: {'l2-ensemble-lr': 0.31742148311349216, 'l2-ensemble-ridge': 0.12583154603466107, 'threshold': 0.42300000000000004}. Best is trial 1 with value: 0.939957356076759.
# [I 2025-07-09 18:23:21,629] Trial 0 finished with value: 0.940817341862118 and parameters: {'l2-ensemble-lr': 0.5266885709757675, 'l2-ensemble-ridge': 0.8094590165453561, 'threshold': 0.5}. Best is trial 0 with value: 0.940817341862118.
# [I 2025-07-09 18:23:21,636] Trial 2 finished with value: 0.9402771855010661 and parameters: {'l2-ensemble-lr': 0.7919238231657364, 'l2-ensemble-ridge': 0.28707430390469546, 'threshold': 0.5650000000000001}. Best is trial 0 with value: 0.940817341862118.
# [I 2025-07-09 18:23:21,642] Trial 3 finished with value: 0.9405828002842929 and parameters: {'l2-ensemble-lr': 0.6427809053875337, 'l2-ensemble-ridge': 0.44963724051847587, 'threshold': 0.532}. Best is trial 0 with value: 0.940817341862118.
# [I 2025-07-09 18:23:21
000000004}. Best is trial 40 with value: 0.9409310589907605.
# [I 2025-07-09 18:23:23,676] Trial 86 finished with value: 0.9408315565031983 and parameters: {'l2-ensemble-lr': 0.5305335411634969, 'l2-ensemble-ridge': 0.01109310172867669, 'threshold': 0.496}. Best is trial 40 with value: 0.9409310589907605.
# [I 2025-07-09 18:23:23,679] Trial 89 finished with value: 0.9408386638237385 and parameters: {'l2-ensemble-lr': 0.5090674886607441, 'l2-ensemble-ridge': 0.021160883606638328, 'threshold': 0.492}. Best is trial 40 with value: 0.9409310589907605.
# [I 2025-07-09 18:23:23,690] Trial 88 finished with value: 0.9408386638237385 and parameters: {'l2-ensemble-lr': 0.5355738739959882, 'l2-ensemble-ridge': 0.030755275452570244, 'threshold': 0.503}. Best is trial 40 with value: 0.9409310589907605.
# [I 2025-07-09 18:23:23,701] Trial 87 finished with value: 0.9408102345415779 and parameters: {'l2-ensemble-lr': 0.47420758543088587, 'l2-ensemble-ridge': 0.12706870535135, 'threshold': 0.48400000000000004}. Best is trial 40 with value: 0.9409310589907605.
# [I 2025-07-09 18:23:23,789] Trial 91 finished with value: 0.940227434257285 and parameters: {'l2-ensemble-lr': 0.017294484805326693, 'l2-ensemble-ridge': 0.6463246580332469, 'threshold': 0.5690000000000001}. Best is trial 40 with value: 0.9409310589907605.
# [I 2025-07-09 18:23:23,801] Trial 93 finished with value: 0.9406467661691542 and parameters: {'l2-ensemble-lr': 0.2424638290408749, 'l2-ensemble-ridge': 0.6907259864841238, 'threshold': 0.524}. Best is trial 40 with value: 0.9409310589907605.
# [I 2025-07-09 18:23:23,802] Trial 90 finished with value: 0.9408386638237385 and parameters: {'l2-ensemble-lr': 0.33227287673029904, 'l2-ensemble-ridge': 0.5609123954010783, 'threshold': 0.495}. Best is trial 40 with value: 0.9409310589907605.
# [I 2025-07-09 18:23:23,803] Trial 92 finished with value: 0.9407818052594172 and parameters: {'l2-ensemble-lr': 0.29725759201584706, 'l2-ensemble-ridge': 0.26952571648217666, 'threshold': 0.48600000000000004}. Best is trial 40 with value: 0.9409310589907605.
# [I 2025-07-09 18:23:23,905] Trial 94 finished with value: 0.9408244491826582 and parameters: {'l2-ensemble-lr': 0.7938120011189052, 'l2-ensemble-ridge': 0.3962999841794036, 'threshold': 0.48700000000000004}. Best is trial 40 with value: 0.9409310589907605.
# [I 2025-07-09 18:23:23,908] Trial 95 finished with value: 0.9405970149253732 and parameters: {'l2-ensemble-lr': 0.7811744347051465, 'l2-ensemble-ridge': 0.15033997094455373, 'threshold': 0.551}. Best is trial 40 with value: 0.9409310589907605.
# [I 2025-07-09 18:23:23,933] Trial 96 finished with value: 0.9407818052594172 and parameters: {'l2-ensemble-lr': 0.6264285700322627, 'l2-ensemble-ridge': 0.16979167664950998, 'threshold': 0.49}. Best is trial 40 with value: 0.9409310589907605.
# [I 2025-07-09 18:23:23,935] Trial 97 finished with value: 0.9408244491826582 and parameters: {'l2-ensemble-lr': 0.6763180047112979, 'l2-ensemble-ridge': 0.104727858417978, 'threshold': 0.518}. Best is trial 40 with value: 0.9409310589907605.
# [I 2025-07-09 18:23:23,977] Trial 98 finished with value: 0.9408813077469794 and parameters: {'l2-ensemble-lr': 0.7976535964694897, 'l2-ensemble-ridge': 0.21273479127255487, 'threshold': 0.505}. Best is trial 40 with value: 0.9409310589907605.
# [I 2025-07-09 18:23:23,979] Trial 99 finished with value: 0.9408742004264392 and parameters: {'l2-ensemble-lr': 0.7038432833702345, 'l2-ensemble-ridge': 0.09713574696579114, 'threshold': 0.499}. Best is trial 40 with value: 0.9409310589907605.

# %%
scores['L3 Weighted Ensemble (LR + Ridge)'] = [study.best_value] * CFG.n_folds

# %%
best_weights = np.array([study.best_params[l2_model] for l2_model in l2_oof_pred_probs.keys()])
best_weights /= np.sum(best_weights)
print(json.dumps({model: weight for model, weight in zip(l2_oof_pred_probs.keys(), best_weights)}, indent=2))

best_threshold = study.best_params['threshold']
print(f'\nBest threshold: {best_threshold:.3f}')
# Out:
# {
#   "l2-ensemble-lr": 0.0009432788675829245,
#   "l2-ensemble-ridge": 0.9990567211324171
# }
#
# Best threshold: 0.492

# %%
plt.figure(figsize=(8, 5))
plt.pie(
    [v for k,v in study.best_params.items() if k != "threshold"], 
    labels=[k for k,v in study.best_params.items() if k != "threshold"], 
    autopct='%1.1f%%',
    colors=sns.color_palette('Set2', 2)
)
plt.title("L3 Ensemble Weights")
plt.tight_layout()
plt.show()

# %% [markdown]
# # Results¶

# %%
weighted_test_preds = np.zeros((X_test.shape[0]))
for model, weight in zip(l2_test_pred_probs.keys(), best_weights):
    weighted_test_preds += l2_test_pred_probs[model] * weight
    
save_submission('l3-weighted-ensemble', weighted_test_preds, np.mean(scores['L3 Weighted Ensemble (LR + Ridge)']), best_threshold)
# Out:
#        id  Depression
# 0  140700           0
# 1  140701           0
# 2  140702           0
# 3  140703           1
# 4  140704           0

# %%
scores = pd.DataFrame(scores)
mean_scores = scores.mean().sort_values(ascending=False)
order = scores.mean().sort_values(ascending=False).index.tolist()

min_score = mean_scores.min()
max_score = mean_scores.max()
padding = (max_score - min_score) * 0.5
lower_limit = min_score - padding
upper_limit = max_score + padding

fig, axs = plt.subplots(1, 2, figsize=(15, scores.shape[1] * 0.3))

boxplot = sns.boxplot(data=scores, order=order, ax=axs[0], orient='h', color='grey')
axs[0].set_title('Fold Accuracy')
axs[0].set_xlabel('')
axs[0].set_ylabel('')

barplot = sns.barplot(x=mean_scores.values, y=mean_scores.index, ax=axs[1], color='grey')
axs[1].set_title('Average Accuracy')
axs[1].set_xlabel('')
axs[1].set_xlim(left=lower_limit, right=upper_limit)
axs[1].set_ylabel('')

for i, (score, model) in enumerate(zip(mean_scores.values, mean_scores.index)):
    color = 'cyan' if 'ensemble' in model.lower() else 'grey'
    barplot.patches[i].set_facecolor(color)
    boxplot.patches[i].set_facecolor(color)
    barplot.text(score, i, round(score, 6), va='center')

plt.tight_layout()
plt.show()

# %%
shutil.rmtree('catboost_info', ignore_errors=True)

# %% [markdown]
# <div style="background-color:green; padding:10px; border-radius:8px; text-align:center;">
#   <h1 style="margin:0; color:white; font-size:24px;">Thank You & Any Question?  </h1>
# </div>
